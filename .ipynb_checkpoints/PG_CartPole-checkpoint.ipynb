# %% [markdown]
# # CartPole with Policy Gradient Method
# In this exercise you will build a policy-gradient based agent that can solve the classic CartPole task where we must balance a pole on a cart for as long as possible. You will specifically be using the OpenAI Gym in order to have a reactive environment that gives you observations (state) and reward with a given action from your model. For those who are not familiar with OpenAI Gym, please check out the short [tutorial](https://gym.openai.com/docs) to cover the basics of the different game environments.

# %%
from __future__ import division

import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

try:
    xrange = xrange
except:
    xrange = range

# %% [markdown]
# ### Loading the CartPole Environment
# If you don't already have the OpenAI gym installed, use  `pip install gym` to grab it.

# %%
import gym
env = gym.make('CartPole-v0')
# Out:
# [2017-09-24 10:50:15,450] Making new env: CartPole-v0

# %% [markdown]
# First, we will run the task using random movements. The cart can either move left or right in order to balance the pole. We will randomly choose which direction to move the cart.

# %% [markdown]
# ## Inline Question 1:
# How well do we do with random action? (Hint: not so well.)

# %%
env.reset()
random_episodes = 0
reward_sum = 0
while random_episodes < 10:
    env.render()
    observation, reward, done, _ = env.step(np.random.randint(0,2))
    reward_sum += reward
    if done:
        random_episodes += 1
        print("Reward for this episode was:",reward_sum)
        reward_sum = 0
        env.reset()
# Out:
# ('Reward for this episode was:', 16.0)
# ('Reward for this episode was:', 21.0)
# ('Reward for this episode was:', 12.0)
# ('Reward for this episode was:', 9.0)
# ('Reward for this episode was:', 12.0)
# ('Reward for this episode was:', 15.0)
# ('Reward for this episode was:', 43.0)
# ('Reward for this episode was:', 27.0)
# ('Reward for this episode was:', 14.0)
# ('Reward for this episode was:', 57.0)

# %% [markdown]
# The goal of the task is to achieve a reward of 200 per episode. For every step the agent keeps the pole in the air, the agent recieves a +1 reward. By randomly choosing actions, our reward for each episode is only a couple dozen. Let's make that better with RL!

# %% [markdown]
# ### Setting up our Neural Network agent
# This time we will be using a Policy neural network that takes observations, passes them through a single hidden layer, and then produces a probability of choosing a left/right movement. To learn more about this network, see [Andrej Karpathy's blog on Policy Gradient networks](http://karpathy.github.io/2016/05/31/rl/).

# %%
# hyperparameters
H = 10 # number of hidden layer neurons
batch_size = 5 # every how many episodes to do a param update?
learning_rate = 1e-2 # feel free to play with this to train faster or more stably.
gamma = 0.99 # discount factor for reward

D = 4 # input dimensionality

# %%
tf.reset_default_graph()

#This defines the network as it goes from taking an observation of the environment to 
#giving a probability of chosing to the action of moving left or right.
observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
W1 = tf.get_variable("W1", shape=[D, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

#From here we define the parts of the network needed for learning a good policy.
tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
pass
loss = -tf.reduce_mean(advantages * tf.log(input_y * (1 - probability) + (1 - input_y) * probability))
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)

# Once we have collected a series of gradients from multiple episodes, we apply them.
# We don't just apply gradeients after every episode in order to account for noise in the reward signal.
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
W1Grad = tf.placeholder(tf.float32,name="batch_grad1") # Placeholders to send the final gradients through when we update.
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Advantage function
# This function allows us to weigh the rewards our agent recieves. In the context of the Cart-Pole task, we want actions that kept the pole in the air a long time to have a large reward, and actions that contributed to the pole falling to have a decreased or negative reward. We do this by weighing the rewards from the end of the episode, with actions at the end being seen as negative, since they likely contributed to the pole falling, and the episode ending. Likewise, early actions are seen as more positive, since they weren't responsible for the pole falling.

# %%
def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    pass
    ret = np.zeros_like(r)
    prev = 0
    for t in reversed(range(0, r.size)):
        ret[t] = r[t] + prev * gamma
        prev = ret[t]
    return ret
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# %% [markdown]
# ### Running the Agent and Environment

# %% [markdown]
# Here we run the neural network agent, and have it act in the CartPole environment.

# %%
xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
total_episodes = 10000
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset() # Obtain an initial observation of the environment

    # Reset the gradient placeholder. We will collect gradients in 
    # gradBuffer until we are ready to update our policy network. 
    gradBuffer = sess.run(tvars)
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    
    while episode_number <= total_episodes:
        
        # Rendering the environment slows things down, 
        # so let's only look at it once our agent is doing a good job.
        if reward_sum/batch_size > 100 or rendering == True : 
            env.render()
            rendering = True
            
        # Make sure the observation is in a shape the network can handle.
        x = np.reshape(observation,[1,D])
        
        
        ################################################################################
        # TODO: Run the policy network and get an action to take.                      #
        # Output: action                                                               #
        ################################################################################
        prob = sess.run(probability, feed_dict={observations: x})
        action = 0
        if np.random.uniform() < prob :
            action = 1
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
             
        xs.append(x) # observation
        y = 1 if action == 0 else 0 # a "fake label"
        ys.append(y)

        ################################################################################
        # TODO: Step the environment and get new measurements                          #
        # Output: observation, reward, done                                            #
        ################################################################################
        pass
        observation, reward, done, _ = env.step(action)
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################

        reward_sum += reward

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            episode_number += 1
            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            tfp = tfps
            xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[] # reset array memory

            # compute the discounted reward backwards through time
            discounted_epr = discount_rewards(epr)
            # size the rewards to be unit normal (helps control the gradient estimator variance)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr //= np.std(discounted_epr)
            
            # Get the gradient for this episode, and save it in the gradBuffer
            tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
            for ix,grad in enumerate(tGrad):
                gradBuffer[ix] += grad
                
            # If we have completed enough episodes
            if episode_number % batch_size == 0: 
                
                ################################################################################
                # TODO: Update the policy network with our gradients and set gradBuffer to 0   #
                ################################################################################
                pass
                sess.run(updateGrads, feed_dict={W1Grad:gradBuffer[0] , W2Grad:gradBuffer[1]})
                for ix,grad in enumerate(gradBuffer):
                    gradBuffer[ix] = grad * 0
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # Give a summary of how well our network is doing for each batch of episodes.
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                print('Average reward for episode %f.  Total average reward %f.' % (reward_sum/batch_size, running_reward/batch_size))
                
                if reward_sum/batch_size > 200: 
                    print("Task solved in",episode_number,'episodes!')
                    break
                    
                reward_sum = 0
            
            observation = env.reset()
        
print(episode_number,'Episodes completed.')
# Out:
# Average reward for episode 15.000000.  Total average reward 15.000000.
# Average reward for episode 27.000000.  Total average reward 15.120000.
# Average reward for episode 25.200000.  Total average reward 15.220800.
# Average reward for episode 17.200000.  Total average reward 15.240592.
# Average reward for episode 22.800000.  Total average reward 15.316186.
# Average reward for episode 22.400000.  Total average reward 15.387024.
# Average reward for episode 18.600000.  Total average reward 15.419154.
# Average reward for episode 23.800000.  Total average reward 15.502962.
# Average reward for episode 25.400000.  Total average reward 15.601933.
# Average reward for episode 49.000000.  Total average reward 15.935913.
# Average reward for episode 17.400000.  Total average reward 15.950554.
# Average reward for episode 14.400000.  Total average reward 15.935049.
# Average reward for episode 31.200000.  Total average reward 16.087698.
# Average reward for episode 34.400000.  Total average reward 16.270821.
# Average reward for episode 33.800000.  Total average reward 16.446113.
# Average reward for episode 27.000000.  Total average reward 16.551652.
# Average reward for episode 18.800000.  Total average reward 16.574135.
# Average reward for episode 25.800000.  Total average reward 16.666394.
# Average reward for episode 23.400000.  Total average reward 16.733730.
# Average reward for episode 29.800000.  Total average reward 16.864393.
# Average reward for episode 19.800000.  Total average reward 16.893749.
# Average reward for episode 30.600000.  Total average reward 17.030811.
# Average reward for episode 44.000000.  Total average reward 17.300503.
# Average reward for episode 33.800000.  Total average reward 17.465498.
# Average reward for episode 29.000000.  Total average reward 17.580843.
# Average reward for episode 29.000000.  Total average reward 17.695035.
# Average reward for episode 25.400000.  Total average reward 17.772085.
# Average reward for episode 21.800000.  Total average reward 17.812364.
# Average reward for episode 39.000000.  Total average reward 18.024240.
# Average reward for episode 37.800000.  Total average reward 18.221998.
# Average reward for episode 35.600000.  Total average reward 18.395778.
# Average reward for episode 22.000000.  Total average reward 18.431820.
# Average reward for episode 30.600000.  Total average reward 18.553502.
# Average reward for episode 33.800000.  Total average reward 18.705967.
# Average reward for episode 34.800000.  Total average reward 18.866907.
# Average reward for episode 37.000000.  Total average reward 19.048238.
# Average reward for episode 20.800000.  Total average reward 19.065756.
# Average reward for episode 30.000000.  Total average reward 19.175098.
# Average reward for episode 55.400000.  Total average reward 19.537347.
# Average reward for episode 42.600000.  Total average reward 19.767974.
# Average reward for episode 41.800000.  Total average reward 19.988294.
# Average reward for episode 58.800000.  Total average reward 20.376411.
# Average reward for episode 26.200000.  Total average reward 20.434647.
# Average reward for episode 44.200000.  Total average reward 20.672300.
# Average reward for episode 39.400000.  Total average reward 20.859577.
# Average reward for episode 43.200000.  Total average reward 21.082982.
# Average reward for episode 23.400000.  Total average reward 21.106152.
# Average reward for episode 39.600000.  Total average reward 21.291090.
# Average reward for episode 66.200000.  Total average reward 21.740179.
# Average reward for episode 24.600000.  Total average reward 21.768778.
# Average reward for episode 59.800000.  Total average reward 22.149090.
# Average reward for episode 29.000000.  Total average reward 22.217599.
# Average reward for episode 43.600000.  Total average reward 22.431423.
# Average reward for episode 37.000000.  Total average reward 22.577109.
# Average reward for episode 78.600000.  Total average reward 23.137338.
# Average reward for episode 40.800000.  Total average reward 23.313964.
# Average reward for episode 36.800000.  Total average reward 23.448825.
# Average reward for episode 39.000000.  Total average reward 23.604336.
# Average reward for episode 58.200000.  Total average reward 23.950293.
# Average reward for episode 48.800000.  Total average reward 24.198790.
# Average reward for episode 44.000000.  Total average reward 24.396802.
# Average reward for episode 43.200000.  Total average reward 24.584834.
# Average reward for episode 30.000000.  Total average reward 24.638986.
# Average reward for episode 53.600000.  Total average reward 24.928596.
# Average reward for episode 60.600000.  Total average reward 25.285310.
# Average reward for episode 77.800000.  Total average reward 25.810457.
# Average reward for episode 40.000000.  Total average reward 25.952352.
# Average reward for episode 159.600000.  Total average reward 57.039130.
# Average reward for episode 134.000000.  Total average reward 57.808739.
# Average reward for episode 167.600000.  Total average reward 58.906652.
# Average reward for episode 138.800000.  Total average reward 59.705585.
# Average reward for episode 175.200000.  Total average reward 60.860529.
# Average reward for episode 114.000000.  Total average reward 61.391924.
# Average reward for episode 149.600000.  Total average reward 62.274005.
# Average reward for episode 172.800000.  Total average reward 63.379265.
# Average reward for episode 148.000000.  Total average reward 64.225472.
# Average reward for episode 150.800000.  Total average reward 65.091217.
# Average reward for episode 144.200000.  Total average reward 65.882305.
# Average reward for episode 157.400000.  Total average reward 66.797482.
# Average reward for episode 165.000000.  Total average reward 67.779507.
# Average reward for episode 138.800000.  Total average reward 68.489712.
# Average reward for episode 103.000000.  Total average reward 68.834815.
# Average reward for episode 134.200000.  Total average reward 69.488467.
# Average reward for episode 160.800000.  Total average reward 70.401582.
# Average reward for episode 147.600000.  Total average reward 71.173566.
# Average reward for episode 154.600000.  Total average reward 72.007831.
# Average reward for episode 181.800000.  Total average reward 73.105752.
# Average reward for episode 131.200000.  Total average reward 73.686695.
# Average reward for episode 167.000000.  Total average reward 74.619828.
# Average reward for episode 200.000000.  Total average reward 75.873630.
# Average reward for episode 192.600000.  Total average reward 77.040893.
# Average reward for episode 140.000000.  Total average reward 77.670484.
# Average reward for episode 162.000000.  Total average reward 78.513780.
# Average reward for episode 184.600000.  Total average reward 79.574642.
# Average reward for episode 191.600000.  Total average reward 80.694895.
# Average reward for episode 186.400000.  Total average reward 81.751946.
# Average reward for episode 156.800000.  Total average reward 82.502427.
# Average reward for episode 152.600000.  Total average reward 83.203403.
# Average reward for episode 183.400000.  Total average reward 84.205369.
# Average reward for episode 172.600000.  Total average reward 85.089315.
# Average reward for episode 152.800000.  Total average reward 85.766422.
# Average reward for episode 186.400000.  Total average reward 86.772758.
# Average reward for episode 187.200000.  Total average reward 87.777030.
# Average reward for episode 163.200000.  Total average reward 88.531260.
# Average reward for episode 153.400000.  Total average reward 89.179947.
# Average reward for episode 105.800000.  Total average reward 89.346148.
# Average reward for episode 160.400000.  Total average reward 90.056686.
# Average reward for episode 165.800000.  Total average reward 90.814119.
# Average reward for episode 166.800000.  Total average reward 91.573978.
# Average reward for episode 193.200000.  Total average reward 92.590238.
# Average reward for episode 182.800000.  Total average reward 93.492336.
# Average reward for episode 177.200000.  Total average reward 94.329413.
# Average reward for episode 150.000000.  Total average reward 94.886118.
# Average reward for episode 166.000000.  Total average reward 95.597257.
# Average reward for episode 198.000000.  Total average reward 96.621285.
# Average reward for episode 181.000000.  Total average reward 97.465072.
# Average reward for episode 154.000000.  Total average reward 98.030421.
# Average reward for episode 178.400000.  Total average reward 98.834117.
# Average reward for episode 191.200000.  Total average reward 99.757776.
# Average reward for episode 189.200000.  Total average reward 100.652198.
# Average reward for episode 175.800000.  Total average reward 101.403676.
# Average reward for episode 190.600000.  Total average reward 102.295639.
# Average reward for episode 193.600000.  Total average reward 103.208683.
# Average reward for episode 123.600000.  Total average reward 103.412596.
# Average reward for episode 197.600000.  Total average reward 160.211086.
# Average reward for episode 199.400000.  Total average reward 160.602975.
# Average reward for episode 155.400000.  Total average reward 160.550945.
# Average reward for episode 192.800000.  Total average reward 160.873436.
# Average reward for episode 195.800000.  Total average reward 161.222702.
# Average reward for episode 187.200000.  Total average reward 161.482475.
# Average reward for episode 173.800000.  Total average reward 161.605650.
# Average reward for episode 200.000000.  Total average reward 161.989593.
# Average reward for episode 191.200000.  Total average reward 162.281697.
# Average reward for episode 187.000000.  Total average reward 162.528880.
# Average reward for episode 188.600000.  Total average reward 162.789592.
# Average reward for episode 191.200000.  Total average reward 163.073696.
# Average reward for episode 188.200000.  Total average reward 163.324959.
# Average reward for episode 198.600000.  Total average reward 163.677709.
# Average reward for episode 193.400000.  Total average reward 163.974932.
# Average reward for episode 186.200000.  Total average reward 164.197183.
# Average reward for episode 200.000000.  Total average reward 164.555211.
# Average reward for episode 178.600000.  Total average reward 164.695659.
# Average reward for episode 165.000000.  Total average reward 164.698702.
# Average reward for episode 200.000000.  Total average reward 165.051715.
# Average reward for episode 195.400000.  Total average reward 165.355198.
# Average reward for episode 193.600000.  Total average reward 165.637646.
# Average reward for episode 193.800000.  Total average reward 165.919270.
# Average reward for episode 191.200000.  Total average reward 166.172077.
# Average reward for episode 190.800000.  Total average reward 166.418356.
# Average reward for episode 193.800000.  Total average reward 166.692173.
# Average reward for episode 191.000000.  Total average reward 166.935251.
# Average reward for episode 183.200000.  Total average reward 167.097898.
# Average reward for episode 178.000000.  Total average reward 167.206919.
# Average reward for episode 180.600000.  Total average reward 167.340850.
# Average reward for episode 185.400000.  Total average reward 167.521442.
# Average reward for episode 160.800000.  Total average reward 167.454227.
# Average reward for episode 200.000000.  Total average reward 167.779685.
# Average reward for episode 186.800000.  Total average reward 167.969888.
# Average reward for episode 144.600000.  Total average reward 167.736189.
# Average reward for episode 192.000000.  Total average reward 167.978827.
# Average reward for episode 191.800000.  Total average reward 168.217039.
# Average reward for episode 192.800000.  Total average reward 168.462869.
# Average reward for episode 167.600000.  Total average reward 168.454240.
# Average reward for episode 168.800000.  Total average reward 168.457698.
# Average reward for episode 166.400000.  Total average reward 168.437121.
# Average reward for episode 179.400000.  Total average reward 168.546749.
# Average reward for episode 188.200000.  Total average reward 168.743282.
# Average reward for episode 199.400000.  Total average reward 169.049849.
# Average reward for episode 168.600000.  Total average reward 169.045351.
# Average reward for episode 176.000000.  Total average reward 169.114897.
# Average reward for episode 185.000000.  Total average reward 169.273748.
# Average reward for episode 172.000000.  Total average reward 169.301011.
# Average reward for episode 200.000000.  Total average reward 169.608001.
# Average reward for episode 194.400000.  Total average reward 169.855921.
# Average reward for episode 190.800000.  Total average reward 170.065361.
# Average reward for episode 189.800000.  Total average reward 170.262708.
# Average reward for episode 200.000000.  Total average reward 170.560081.
# Average reward for episode 200.000000.  Total average reward 170.854480.
# Average reward for episode 191.600000.  Total average reward 171.061935.
# Average reward for episode 171.800000.  Total average reward 171.069316.
# Average reward for episode 185.000000.  Total average reward 171.208623.
# Average reward for episode 177.600000.  Total average reward 171.272536.
# Average reward for episode 198.000000.  Total average reward 180.554306.
# Average reward for episode 192.800000.  Total average reward 180.676763.
# Average reward for episode 195.600000.  Total average reward 180.825995.
# Average reward for episode 194.200000.  Total average reward 180.959736.
# Average reward for episode 199.200000.  Total average reward 181.142138.
# Average reward for episode 200.000000.  Total average reward 181.330717.
# Average reward for episode 195.800000.  Total average reward 181.475410.
# Average reward for episode 200.000000.  Total average reward 181.660656.
# Average reward for episode 199.000000.  Total average reward 181.834049.
# Average reward for episode 200.000000.  Total average reward 182.015708.
# Average reward for episode 193.400000.  Total average reward 182.129551.
# Average reward for episode 186.400000.  Total average reward 182.172256.
# Average reward for episode 197.400000.  Total average reward 182.324533.
# Average reward for episode 198.800000.  Total average reward 182.489288.
# Average reward for episode 199.800000.  Total average reward 182.662395.
# Average reward for episode 200.000000.  Total average reward 182.835771.
# Average reward for episode 200.000000.  Total average reward 183.007413.
# Average reward for episode 200.000000.  Total average reward 183.177339.
# Average reward for episode 200.000000.  Total average reward 183.345566.
# Average reward for episode 194.400000.  Total average reward 183.456110.
# Average reward for episode 193.200000.  Total average reward 183.553549.
# Average reward for episode 200.000000.  Total average reward 183.718014.
# Average reward for episode 200.000000.  Total average reward 183.880834.
# Average reward for episode 186.600000.  Total average reward 183.908025.
# Average reward for episode 200.000000.  Total average reward 184.068945.
# Average reward for episode 200.000000.  Total average reward 184.228255.
# Average reward for episode 191.600000.  Total average reward 184.301973.
# Average reward for episode 200.000000.  Total average reward 184.458953.
# Average reward for episode 187.200000.  Total average reward 184.486364.
# Average reward for episode 187.000000.  Total average reward 184.511500.
# Average reward for episode 200.000000.  Total average reward 184.666385.
# Average reward for episode 200.000000.  Total average reward 184.819721.
# Average reward for episode 200.000000.  Total average reward 184.971524.
# Average reward for episode 200.000000.  Total average reward 185.121809.
# Average reward for episode 200.000000.  Total average reward 185.270591.
# Average reward for episode 200.000000.  Total average reward 185.417885.
# Average reward for episode 200.000000.  Total average reward 185.563706.
# Average reward for episode 200.000000.  Total average reward 185.708069.
# Average reward for episode 187.600000.  Total average reward 185.726988.
# Average reward for episode 188.600000.  Total average reward 185.755718.
# Average reward for episode 188.200000.  Total average reward 185.780161.
# Average reward for episode 200.000000.  Total average reward 185.922359.
# Average reward for episode 200.000000.  Total average reward 186.063136.
# Average reward for episode 200.000000.  Total average reward 186.202505.
# Average reward for episode 191.800000.  Total average reward 186.258479.
# Average reward for episode 193.000000.  Total average reward 186.325895.
# Average reward for episode 200.000000.  Total average reward 186.462636.
# Average reward for episode 177.800000.  Total average reward 186.376009.
# Average reward for episode 166.200000.  Total average reward 186.174249.
# Average reward for episode 192.200000.  Total average reward 186.234507.
# Average reward for episode 190.400000.  Total average reward 186.276162.
# Average reward for episode 188.000000.  Total average reward 186.293400.
# Average reward for episode 180.400000.  Total average reward 186.234466.
# Average reward for episode 178.000000.  Total average reward 186.152121.
# Average reward for episode 179.200000.  Total average reward 186.082600.
# Average reward for episode 198.400000.  Total average reward 186.205774.
# Average reward for episode 200.000000.  Total average reward 186.343716.
# Average reward for episode 195.200000.  Total average reward 186.432279.
# Average reward for episode 183.800000.  Total average reward 186.405957.
# Average reward for episode 200.000000.  Total average reward 186.541897.
# Average reward for episode 181.000000.  Total average reward 186.486478.
# Average reward for episode 200.000000.  Total average reward 186.621613.
# Average reward for episode 196.800000.  Total average reward 186.723397.
# Average reward for episode 196.000000.  Total average reward 186.816163.
# Average reward for episode 184.200000.  Total average reward 186.790001.
# Average reward for episode 190.800000.  Total average reward 186.830101.
# Average reward for episode 198.400000.  Total average reward 186.945800.
# Average reward for episode 191.400000.  Total average reward 186.990342.
# Average reward for episode 176.600000.  Total average reward 186.886439.
# Average reward for episode 200.000000.  Total average reward 187.017575.
# Average reward for episode 189.400000.  Total average reward 187.041399.
# Average reward for episode 194.000000.  Total average reward 187.110985.
# Average reward for episode 200.000000.  Total average reward 187.239875.
# Average reward for episode 181.400000.  Total average reward 187.181476.
# Average reward for episode 182.800000.  Total average reward 187.137662.
# Average reward for episode 164.000000.  Total average reward 186.906285.
# Average reward for episode 187.000000.  Total average reward 186.907222.
# Average reward for episode 174.600000.  Total average reward 186.784150.
# Average reward for episode 182.000000.  Total average reward 186.736308.
# Average reward for episode 200.000000.  Total average reward 186.868945.
# Average reward for episode 192.200000.  Total average reward 186.922256.
# Average reward for episode 189.800000.  Total average reward 186.951033.
# Average reward for episode 188.800000.  Total average reward 186.969523.
# Average reward for episode 200.000000.  Total average reward 187.099828.
# Average reward for episode 199.200000.  Total average reward 187.220829.
# Average reward for episode 200.000000.  Total average reward 187.348621.
# Average reward for episode 200.000000.  Total average reward 187.475135.
# Average reward for episode 200.000000.  Total average reward 187.600384.
# Average reward for episode 200.000000.  Total average reward 187.724380.
# Average reward for episode 185.400000.  Total average reward 187.701136.
# Average reward for episode 200.000000.  Total average reward 187.824125.
# Average reward for episode 200.000000.  Total average reward 187.945883.
# Average reward for episode 200.000000.  Total average reward 188.066424.
# Average reward for episode 200.000000.  Total average reward 188.185760.
# Average reward for episode 196.400000.  Total average reward 188.267903.
# Average reward for episode 200.000000.  Total average reward 188.385224.
# Average reward for episode 196.800000.  Total average reward 188.469371.
# Average reward for episode 200.000000.  Total average reward 188.584678.
# Average reward for episode 200.000000.  Total average reward 188.698831.
# Average reward for episode 198.400000.  Total average reward 188.795843.
# Average reward for episode 198.800000.  Total average reward 188.895884.
# Average reward for episode 200.000000.  Total average reward 189.006925.
# Average reward for episode 200.000000.  Total average reward 189.116856.
# Average reward for episode 200.000000.  Total average reward 189.225687.
# Average reward for episode 200.000000.  Total average reward 189.333431.
# Average reward for episode 200.000000.  Total average reward 189.440096.
# Average reward for episode 200.000000.  Total average reward 189.545695.
# Average reward for episode 192.000000.  Total average reward 189.570238.
# Average reward for episode 200.000000.  Total average reward 189.674536.
# Average reward for episode 200.000000.  Total average reward 189.777791.
# Average reward for episode 200.000000.  Total average reward 189.880013.
# Average reward for episode 200.000000.  Total average reward 189.981213.
# Average reward for episode 200.000000.  Total average reward 190.081400.
# Average reward for episode 200.000000.  Total average reward 190.180586.
# Average reward for episode 200.000000.  Total average reward 190.278781.
# Average reward for episode 192.800000.  Total average reward 190.303993.
# Average reward for episode 193.000000.  Total average reward 190.330953.
# Average reward for episode 200.000000.  Total average reward 190.427643.
# Average reward for episode 200.000000.  Total average reward 190.523367.
# Average reward for episode 200.000000.  Total average reward 190.618133.
# Average reward for episode 200.000000.  Total average reward 190.711952.
# Average reward for episode 200.000000.  Total average reward 190.804832.
# Average reward for episode 200.000000.  Total average reward 190.896784.
# Average reward for episode 200.000000.  Total average reward 190.987816.
# Average reward for episode 200.000000.  Total average reward 191.077938.
# Average reward for episode 200.000000.  Total average reward 191.167159.
# Average reward for episode 200.000000.  Total average reward 191.255487.
# Average reward for episode 200.000000.  Total average reward 191.342932.
# Average reward for episode 192.600000.  Total average reward 191.355503.
# Average reward for episode 200.000000.  Total average reward 191.441948.
# Average reward for episode 199.400000.  Total average reward 191.521528.
# Average reward for episode 183.400000.  Total average reward 191.440313.
# Average reward for episode 200.000000.  Total average reward 191.525910.
# Average reward for episode 200.000000.  Total average reward 191.610651.
# Average reward for episode 200.000000.  Total average reward 191.694544.
# Average reward for episode 200.000000.  Total average reward 191.777599.
# Average reward for episode 200.000000.  Total average reward 191.859823.
# Average reward for episode 196.400000.  Total average reward 191.905225.
# Average reward for episode 200.000000.  Total average reward 191.986172.
# Average reward for episode 200.000000.  Total average reward 192.066311.
# Average reward for episode 190.800000.  Total average reward 192.053648.
# Average reward for episode 200.000000.  Total average reward 192.133111.
# Average reward for episode 200.000000.  Total average reward 192.211780.
# Average reward for episode 200.000000.  Total average reward 192.289662.
# Average reward for episode 200.000000.  Total average reward 192.366766.
# Average reward for episode 188.400000.  Total average reward 192.327098.
# Average reward for episode 199.200000.  Total average reward 192.395827.
# Average reward for episode 200.000000.  Total average reward 192.471869.
# Average reward for episode 190.800000.  Total average reward 192.455150.
# Average reward for episode 200.000000.  Total average reward 192.530599.
# Average reward for episode 199.800000.  Total average reward 192.603293.
# Average reward for episode 200.000000.  Total average reward 192.677260.
# Average reward for episode 200.000000.  Total average reward 192.750487.
# Average reward for episode 200.000000.  Total average reward 192.822982.
# Average reward for episode 200.000000.  Total average reward 192.894752.
# Average reward for episode 200.000000.  Total average reward 192.965805.
# Average reward for episode 200.000000.  Total average reward 193.036147.
# Average reward for episode 200.000000.  Total average reward 193.105785.
# Average reward for episode 197.400000.  Total average reward 193.148727.
# Average reward for episode 200.000000.  Total average reward 193.217240.
# Average reward for episode 200.000000.  Total average reward 193.285068.
# Average reward for episode 200.000000.  Total average reward 193.352217.
# Average reward for episode 200.000000.  Total average reward 193.418695.
# Average reward for episode 196.200000.  Total average reward 193.446508.
# Average reward for episode 200.000000.  Total average reward 193.512043.
# Average reward for episode 197.800000.  Total average reward 193.554922.
# Average reward for episode 200.000000.  Total average reward 193.619373.
# Average reward for episode 200.000000.  Total average reward 193.683180.
# Average reward for episode 200.000000.  Total average reward 193.746348.
# Average reward for episode 200.000000.  Total average reward 193.808884.
# Average reward for episode 195.200000.  Total average reward 193.822795.
# Average reward for episode 200.000000.  Total average reward 193.884567.
# Average reward for episode 198.600000.  Total average reward 193.931722.
# Average reward for episode 200.000000.  Total average reward 193.992405.
# Average reward for episode 196.600000.  Total average reward 194.018480.
# Average reward for episode 200.000000.  Total average reward 194.078296.
# Average reward for episode 199.400000.  Total average reward 194.131513.
# Average reward for episode 199.800000.  Total average reward 194.188198.
# Average reward for episode 200.000000.  Total average reward 194.246316.
# Average reward for episode 198.800000.  Total average reward 194.291852.
# Average reward for episode 200.000000.  Total average reward 194.348934.
# Average reward for episode 200.000000.  Total average reward 194.405445.
# Average reward for episode 200.000000.  Total average reward 194.461390.
# Average reward for episode 200.000000.  Total average reward 194.516776.
# Average reward for episode 200.000000.  Total average reward 194.571609.
# Average reward for episode 200.000000.  Total average reward 194.625892.
# Average reward for episode 200.000000.  Total average reward 194.679633.
# Average reward for episode 200.000000.  Total average reward 194.732837.
# Average reward for episode 200.000000.  Total average reward 194.785509.
# Average reward for episode 195.600000.  Total average reward 194.793654.
# Average reward for episode 191.400000.  Total average reward 194.759717.
# Average reward for episode 200.000000.  Total average reward 194.812120.
# Average reward for episode 198.800000.  Total average reward 194.851999.
# Average reward for episode 200.000000.  Total average reward 194.903479.
# Average reward for episode 200.000000.  Total average reward 194.954444.
# Average reward for episode 200.000000.  Total average reward 195.004900.
# Average reward for episode 195.800000.  Total average reward 195.012851.
# Average reward for episode 200.000000.  Total average reward 195.062722.
# Average reward for episode 200.000000.  Total average reward 195.112095.
# Average reward for episode 200.000000.  Total average reward 195.160974.
# Average reward for episode 200.000000.  Total average reward 195.209364.
# Average reward for episode 200.000000.  Total average reward 195.257271.
# Average reward for episode 200.000000.  Total average reward 195.304698.
# Average reward for episode 199.200000.  Total average reward 195.343651.
# Average reward for episode 200.000000.  Total average reward 195.390214.
# Average reward for episode 200.000000.  Total average reward 195.436312.
# Average reward for episode 188.400000.  Total average reward 195.365949.
# Average reward for episode 200.000000.  Total average reward 195.412290.
# Average reward for episode 200.000000.  Total average reward 195.458167.
# Average reward for episode 200.000000.  Total average reward 195.503585.
# Average reward for episode 200.000000.  Total average reward 195.548549.
# Average reward for episode 189.200000.  Total average reward 195.485064.
# Average reward for episode 200.000000.  Total average reward 195.530213.
# Average reward for episode 200.000000.  Total average reward 195.574911.
# Average reward for episode 200.000000.  Total average reward 195.619162.
# Average reward for episode 200.000000.  Total average reward 195.662970.
# Average reward for episode 200.000000.  Total average reward 195.706340.
# Average reward for episode 200.000000.  Total average reward 195.749277.
# Average reward for episode 200.000000.  Total average reward 195.791784.
# Average reward for episode 197.000000.  Total average reward 195.803866.
# Average reward for episode 200.000000.  Total average reward 195.845828.
# Average reward for episode 200.000000.  Total average reward 195.887370.
# Average reward for episode 200.000000.  Total average reward 195.928496.
# Average reward for episode 189.000000.  Total average reward 195.859211.
# Average reward for episode 200.000000.  Total average reward 195.900619.
# Average reward for episode 200.000000.  Total average reward 195.941613.
# Average reward for episode 200.000000.  Total average reward 195.982196.
# Average reward for episode 200.000000.  Total average reward 196.022374.
# Average reward for episode 200.000000.  Total average reward 196.062151.
# Average reward for episode 199.400000.  Total average reward 196.095529.
# Average reward for episode 200.000000.  Total average reward 196.134574.
# Average reward for episode 200.000000.  Total average reward 196.173228.
# Average reward for episode 200.000000.  Total average reward 196.211496.
# Average reward for episode 200.000000.  Total average reward 196.249381.
# Average reward for episode 200.000000.  Total average reward 196.286887.
# Average reward for episode 200.000000.  Total average reward 196.324018.
# Average reward for episode 200.000000.  Total average reward 196.360778.
# Average reward for episode 200.000000.  Total average reward 196.397170.
# Average reward for episode 200.000000.  Total average reward 196.433199.
# Average reward for episode 200.000000.  Total average reward 196.468867.
# Average reward for episode 199.200000.  Total average reward 196.496178.
# Average reward for episode 200.000000.  Total average reward 196.531216.
# Average reward for episode 197.800000.  Total average reward 196.543904.
# Average reward for episode 200.000000.  Total average reward 196.578465.
# Average reward for episode 200.000000.  Total average reward 196.612680.
# Average reward for episode 188.600000.  Total average reward 196.532554.
# Average reward for episode 190.600000.  Total average reward 196.473228.
# Average reward for episode 200.000000.  Total average reward 196.508496.
# Average reward for episode 200.000000.  Total average reward 196.543411.
# Average reward for episode 198.800000.  Total average reward 196.565977.
# ...
# Average reward for episode 200.000000.  Total average reward 198.918334.
# Average reward for episode 200.000000.  Total average reward 198.929151.
# Average reward for episode 200.000000.  Total average reward 198.939859.
# Average reward for episode 200.000000.  Total average reward 198.950460.
# Average reward for episode 200.000000.  Total average reward 198.960956.
# Average reward for episode 200.000000.  Total average reward 198.971346.
# Average reward for episode 200.000000.  Total average reward 198.981633.
# Average reward for episode 200.000000.  Total average reward 198.991817.
# Average reward for episode 200.000000.  Total average reward 199.001898.
# Average reward for episode 175.200000.  Total average reward 198.763879.
# Average reward for episode 200.000000.  Total average reward 198.776241.
# Average reward for episode 196.400000.  Total average reward 198.752478.
# Average reward for episode 200.000000.  Total average reward 198.764953.
# Average reward for episode 200.000000.  Total average reward 198.777304.
# Average reward for episode 196.800000.  Total average reward 198.757531.
# Average reward for episode 200.000000.  Total average reward 198.769956.
# Average reward for episode 197.200000.  Total average reward 198.754256.
# Average reward for episode 200.000000.  Total average reward 198.766713.
# Average reward for episode 200.000000.  Total average reward 198.779046.
# Average reward for episode 200.000000.  Total average reward 198.791256.
# Average reward for episode 196.600000.  Total average reward 198.769343.
# Average reward for episode 200.000000.  Total average reward 198.781650.
# Average reward for episode 200.000000.  Total average reward 198.793833.
# Average reward for episode 200.000000.  Total average reward 198.805895.
# Average reward for episode 200.000000.  Total average reward 198.817836.
# Average reward for episode 200.000000.  Total average reward 198.829658.
# Average reward for episode 196.400000.  Total average reward 198.805361.
# Average reward for episode 191.800000.  Total average reward 198.735307.
# Average reward for episode 197.000000.  Total average reward 198.717954.
# Average reward for episode 191.200000.  Total average reward 198.642775.
# Average reward for episode 200.000000.  Total average reward 198.656347.
# Average reward for episode 199.000000.  Total average reward 198.659784.
# Average reward for episode 189.800000.  Total average reward 198.571186.
# Average reward for episode 200.000000.  Total average reward 198.585474.
# Average reward for episode 200.000000.  Total average reward 198.599619.
# Average reward for episode 200.000000.  Total average reward 198.613623.
# Average reward for episode 200.000000.  Total average reward 198.627487.
# Average reward for episode 200.000000.  Total average reward 198.641212.
# Average reward for episode 200.000000.  Total average reward 198.654800.
# Average reward for episode 196.800000.  Total average reward 198.636252.
# Average reward for episode 200.000000.  Total average reward 198.649889.
# Average reward for episode 200.000000.  Total average reward 198.663390.
# Average reward for episode 200.000000.  Total average reward 198.676756.
# Average reward for episode 200.000000.  Total average reward 198.689989.
# Average reward for episode 200.000000.  Total average reward 198.703089.
# Average reward for episode 200.000000.  Total average reward 198.716058.
# Average reward for episode 200.000000.  Total average reward 198.728898.
# Average reward for episode 200.000000.  Total average reward 198.741609.
# Average reward for episode 200.000000.  Total average reward 198.754193.
# Average reward for episode 200.000000.  Total average reward 198.766651.
# Average reward for episode 200.000000.  Total average reward 198.778984.
# Average reward for episode 200.000000.  Total average reward 198.791194.
# Average reward for episode 200.000000.  Total average reward 198.803282.
# Average reward for episode 200.000000.  Total average reward 198.815249.
# Average reward for episode 200.000000.  Total average reward 198.827097.
# Average reward for episode 200.000000.  Total average reward 198.838826.
# Average reward for episode 200.000000.  Total average reward 198.850438.
# Average reward for episode 200.000000.  Total average reward 198.861933.
# Average reward for episode 200.000000.  Total average reward 198.873314.
# Average reward for episode 200.000000.  Total average reward 198.884581.
# Average reward for episode 200.000000.  Total average reward 198.895735.
# Average reward for episode 200.000000.  Total average reward 198.906778.
# Average reward for episode 200.000000.  Total average reward 198.917710.
# Average reward for episode 200.000000.  Total average reward 198.928533.
# Average reward for episode 200.000000.  Total average reward 198.939248.
# Average reward for episode 200.000000.  Total average reward 198.949855.
# Average reward for episode 200.000000.  Total average reward 198.960357.
# Average reward for episode 200.000000.  Total average reward 198.970753.
# Average reward for episode 200.000000.  Total average reward 198.981045.
# Average reward for episode 197.400000.  Total average reward 198.965235.
# Average reward for episode 200.000000.  Total average reward 198.975583.
# Average reward for episode 200.000000.  Total average reward 198.985827.
# Average reward for episode 200.000000.  Total average reward 198.995969.
# Average reward for episode 200.000000.  Total average reward 199.006009.
# Average reward for episode 200.000000.  Total average reward 199.015949.
# Average reward for episode 200.000000.  Total average reward 199.025789.
# Average reward for episode 200.000000.  Total average reward 199.035531.
# Average reward for episode 200.000000.  Total average reward 199.045176.
# Average reward for episode 200.000000.  Total average reward 199.054724.
# Average reward for episode 200.000000.  Total average reward 199.064177.
# Average reward for episode 200.000000.  Total average reward 199.073535.
# Average reward for episode 200.000000.  Total average reward 199.082800.
# Average reward for episode 200.000000.  Total average reward 199.091972.
# Average reward for episode 200.000000.  Total average reward 199.101052.
# Average reward for episode 200.000000.  Total average reward 199.110042.
# Average reward for episode 200.000000.  Total average reward 199.118941.
# Average reward for episode 200.000000.  Total average reward 199.127752.
# Average reward for episode 200.000000.  Total average reward 199.136474.
# Average reward for episode 180.400000.  Total average reward 198.949110.
# Average reward for episode 200.000000.  Total average reward 198.959618.
# Average reward for episode 200.000000.  Total average reward 198.970022.
# Average reward for episode 200.000000.  Total average reward 198.980322.
# Average reward for episode 200.000000.  Total average reward 198.990519.
# Average reward for episode 200.000000.  Total average reward 199.000614.
# Average reward for episode 200.000000.  Total average reward 199.010608.
# Average reward for episode 200.000000.  Total average reward 199.020501.
# Average reward for episode 200.000000.  Total average reward 199.030296.
# Average reward for episode 200.000000.  Total average reward 199.039993.
# Average reward for episode 200.000000.  Total average reward 199.049594.
# Average reward for episode 200.000000.  Total average reward 199.059098.
# Average reward for episode 200.000000.  Total average reward 199.068507.
# Average reward for episode 200.000000.  Total average reward 199.077822.
# Average reward for episode 200.000000.  Total average reward 199.087043.
# Average reward for episode 200.000000.  Total average reward 199.096173.
# Average reward for episode 200.000000.  Total average reward 199.105211.
# Average reward for episode 200.000000.  Total average reward 199.114159.
# Average reward for episode 200.000000.  Total average reward 199.123017.
# Average reward for episode 200.000000.  Total average reward 199.131787.
# Average reward for episode 200.000000.  Total average reward 199.140469.
# Average reward for episode 189.000000.  Total average reward 199.039065.
# Average reward for episode 200.000000.  Total average reward 199.048674.
# Average reward for episode 200.000000.  Total average reward 199.058187.
# Average reward for episode 200.000000.  Total average reward 199.067605.
# Average reward for episode 200.000000.  Total average reward 199.076929.
# Average reward for episode 200.000000.  Total average reward 199.086160.
# Average reward for episode 200.000000.  Total average reward 199.095299.
# Average reward for episode 200.000000.  Total average reward 199.104346.
# Average reward for episode 200.000000.  Total average reward 199.113302.
# Average reward for episode 200.000000.  Total average reward 199.122169.
# Average reward for episode 200.000000.  Total average reward 199.130947.
# Average reward for episode 200.000000.  Total average reward 199.139638.
# Average reward for episode 200.000000.  Total average reward 199.148242.
# Average reward for episode 200.000000.  Total average reward 199.156759.
# Average reward for episode 199.600000.  Total average reward 199.161192.
# Average reward for episode 200.000000.  Total average reward 199.169580.
# Average reward for episode 200.000000.  Total average reward 199.177884.
# Average reward for episode 200.000000.  Total average reward 199.186105.
# Average reward for episode 200.000000.  Total average reward 199.194244.
# Average reward for episode 200.000000.  Total average reward 199.202301.
# Average reward for episode 200.000000.  Total average reward 199.210278.
# Average reward for episode 200.000000.  Total average reward 199.218176.
# Average reward for episode 200.000000.  Total average reward 199.225994.
# Average reward for episode 200.000000.  Total average reward 199.233734.
# Average reward for episode 200.000000.  Total average reward 199.241397.
# Average reward for episode 200.000000.  Total average reward 199.248983.
# Average reward for episode 200.000000.  Total average reward 199.256493.
# Average reward for episode 200.000000.  Total average reward 199.263928.
# Average reward for episode 200.000000.  Total average reward 199.271289.
# Average reward for episode 200.000000.  Total average reward 199.278576.
# Average reward for episode 200.000000.  Total average reward 199.285790.
# Average reward for episode 200.000000.  Total average reward 199.292932.
# Average reward for episode 200.000000.  Total average reward 199.300003.
# Average reward for episode 200.000000.  Total average reward 199.307003.
# Average reward for episode 200.000000.  Total average reward 199.313933.
# Average reward for episode 200.000000.  Total average reward 199.320793.
# Average reward for episode 200.000000.  Total average reward 199.327585.
# Average reward for episode 200.000000.  Total average reward 199.334310.
# Average reward for episode 200.000000.  Total average reward 199.340967.
# Average reward for episode 200.000000.  Total average reward 199.347557.
# Average reward for episode 200.000000.  Total average reward 199.354081.
# Average reward for episode 200.000000.  Total average reward 199.360540.
# Average reward for episode 200.000000.  Total average reward 199.366935.
# Average reward for episode 200.000000.  Total average reward 199.373266.
# Average reward for episode 200.000000.  Total average reward 199.379533.
# Average reward for episode 200.000000.  Total average reward 199.385738.
# Average reward for episode 200.000000.  Total average reward 199.391880.
# Average reward for episode 200.000000.  Total average reward 199.397962.
# Average reward for episode 200.000000.  Total average reward 199.403982.
# Average reward for episode 200.000000.  Total average reward 199.409942.
# Average reward for episode 200.000000.  Total average reward 199.415843.
# Average reward for episode 200.000000.  Total average reward 199.421684.
# Average reward for episode 200.000000.  Total average reward 199.427467.
# Average reward for episode 200.000000.  Total average reward 199.433193.
# Average reward for episode 200.000000.  Total average reward 199.438861.
# Average reward for episode 200.000000.  Total average reward 199.444472.
# Average reward for episode 200.000000.  Total average reward 199.450027.
# Average reward for episode 200.000000.  Total average reward 199.455527.
# Average reward for episode 200.000000.  Total average reward 199.460972.
# Average reward for episode 200.000000.  Total average reward 199.466362.
# Average reward for episode 200.000000.  Total average reward 199.471699.
# Average reward for episode 200.000000.  Total average reward 199.476982.
# Average reward for episode 200.000000.  Total average reward 199.482212.
# Average reward for episode 200.000000.  Total average reward 199.487390.
# Average reward for episode 200.000000.  Total average reward 199.492516.
# Average reward for episode 200.000000.  Total average reward 199.497591.
# Average reward for episode 200.000000.  Total average reward 199.502615.
# Average reward for episode 200.000000.  Total average reward 199.507589.
# Average reward for episode 200.000000.  Total average reward 199.512513.
# Average reward for episode 200.000000.  Total average reward 199.517388.
# Average reward for episode 200.000000.  Total average reward 199.522214.
# Average reward for episode 200.000000.  Total average reward 199.526992.
# Average reward for episode 200.000000.  Total average reward 199.531722.
# Average reward for episode 200.000000.  Total average reward 199.536404.
# Average reward for episode 200.000000.  Total average reward 199.541040.
# Average reward for episode 200.000000.  Total average reward 199.545630.
# Average reward for episode 190.000000.  Total average reward 199.450174.
# Average reward for episode 200.000000.  Total average reward 199.455672.
# Average reward for episode 200.000000.  Total average reward 199.461115.
# Average reward for episode 200.000000.  Total average reward 199.466504.
# Average reward for episode 200.000000.  Total average reward 199.471839.
# Average reward for episode 200.000000.  Total average reward 199.477121.
# Average reward for episode 200.000000.  Total average reward 199.482349.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e0ff0bb0375f> in <module>()
#      23         # so let's only look at it once our agent is doing a good job.
#      24         if reward_sum/batch_size > 100 or rendering == True :
# ---> 25             env.render()
#      26             rendering = True
#      27
#
# /usr/local/lib/python2.7/site-packages/gym/core.pyc in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# /usr/local/lib/python2.7/site-packages/gym/core.pyc in _render(self, mode, close)
#     284
#     285     def _render(self, mode='human', close=False):
# --> 286         return self.env.render(mode, close)
#     287
#     288     def _close(self):
#
# /usr/local/lib/python2.7/site-packages/gym/core.pyc in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# /usr/local/lib/python2.7/site-packages/gym/envs/classic_control/cartpole.pyc in _render(self, mode, close)
#     144         self.poletrans.set_rotation(-x[2])
#     145
# --> 146         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# /usr/local/lib/python2.7/site-packages/gym/envs/classic_control/rendering.pyc in render(self, return_rgb_array)
#     103             arr = arr[::-1,:,0:3]
#     104         self.window.flip()
# --> 105         self.onetime_geoms = []
#     106         return arr
#     107
#
# KeyboardInterrupt:

# %% [markdown]
# As you can see, the network not only does much better than random actions, but achieves the goal of 200 points per episode, thus solving the task!
